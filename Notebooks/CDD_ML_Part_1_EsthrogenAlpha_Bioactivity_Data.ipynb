# %% [markdown]
# # **Bioinformatics Project - Computational Drug Discovery**
#
# In this Jupyter notebook, I will be building a **data science project**. Particularly, we will be building a machine learning model using the ChEMBL bioactivity data.
#
# In **Part 1**, we will be performing Data Collection and Pre-Processing from the ChEMBL Database.

# %% [markdown]
# The first code below informs you of the directory you are working in.

# %%
import os 
os.getcwd()
# Out:
# 'C:\\Users\\Mychael\\Downloads'

# %% [markdown]
# ## **ChEMBL Database**
#
# The [*ChEMBL Database*](https://www.ebi.ac.uk/chembl/) is a database that contains curated bioactivity data of more than 2 million compounds. It is compiled from more than 76,000 documents, 1.2 million assays and the data spans 13,000 targets and 1,800 cells and 33,000 indications.
# [Data as of March 2024; ChEMBL version 34].

# %% [markdown]
# ## **Installing libraries**

# %% [markdown]
# Install the ChEMBL web service package so that we can retrieve bioactivity data from the ChEMBL Database.

# %%
! pip install chembl_webresource_client
# Out:
# Requirement already satisfied: chembl_webresource_client in c:\users\mychael\anaconda3\lib\site-packages (0.10.9)
# Requirement already satisfied: urllib3 in c:\users\mychael\anaconda3\lib\site-packages (from chembl_webresource_client) (2.0.7)
# Requirement already satisfied: requests>=2.18.4 in c:\users\mychael\anaconda3\lib\site-packages (from chembl_webresource_client) (2.31.0)
# Requirement already satisfied: requests-cache~=1.2 in c:\users\mychael\anaconda3\lib\site-packages (from chembl_webresource_client) (1.2.0)
# Requirement already satisfied: easydict in c:\users\mychael\anaconda3\lib\site-packages (from chembl_webresource_client) (1.13)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\mychael\anaconda3\lib\site-packages (from requests>=2.18.4->chembl_webresource_client) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\mychael\anaconda3\lib\site-packages (from requests>=2.18.4->chembl_webresource_client) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\mychael\anaconda3\lib\site-packages (from requests>=2.18.4->chembl_webresource_client) (2024.7.4)
# Requirement already satisfied: attrs>=21.2 in c:\users\mychael\anaconda3\lib\site-packages (from requests-cache~=1.2->chembl_webresource_client) (23.2.0)
# Requirement already satisfied: cattrs>=22.2 in c:\users\mychael\anaconda3\lib\site-packages (from requests-cache~=1.2->chembl_webresource_client) (23.2.3)
# Requirement already satisfied: platformdirs>=2.5 in c:\users\mychael\anaconda3\lib\site-packages (from requests-cache~=1.2->chembl_webresource_client) (3.10.0)
# Requirement already satisfied: url-normalize>=1.4 in c:\users\mychael\anaconda3\lib\site-packages (from requests-cache~=1.2->chembl_webresource_client) (1.4.3)
# Requirement already satisfied: six in c:\users\mychael\anaconda3\lib\site-packages (from url-normalize>=1.4->requests-cache~=1.2->chembl_webresource_client) (1.16.0)

# %% [markdown]
# ## **Importing libraries**

# %%
# Import necessary libraries
import pandas as pd
from chembl_webresource_client.new_client import new_client

# %% [markdown]
# ## **Search for Target protein**

# %% [markdown]
# ### **Target search for Esthrogen Receptor Alpha**

# %%
target = new_client.target
target_query = target.search('CHEMBL206')
targets = pd.DataFrame.from_dict(target_query)
targets
# Out:
#                                     cross_references      organism  \
# 0  [{'xref_id': 'P19785', 'xref_name': None, 'xre...  Mus musculus
# 1                                                 []  Mus musculus
#
#                  pref_name  score  species_group_flag target_chembl_id  \
# 0  Estrogen receptor alpha   15.0               False       CHEMBL3065
# 1        Estrogen receptor   12.0               False    CHEMBL2094113
#
#                                    target_components     target_type  tax_id
# 0  [{'accession': 'P19785', 'component_descriptio...  SINGLE PROTEIN   10090
# 1  [{'accession': 'O08537', 'component_descriptio...  PROTEIN FAMILY   10090

# %% [markdown]
# ### **Select and retrieve bioactivity data for *Human Esthrogen Receptor Alpha* (first entry)**

# %% [markdown]
# We will assign the first entry (which corresponds to the target protein, *Human Esthrogen Receptor Alpha*) to the ***selected_target*** variable

# %%
selected_target = targets.target_chembl_id[0]
selected_target
# Out:
# 'CHEMBL3065'

# %% [markdown]
# Here, we will retrieve only bioactivity data for *Human Esthrogen Receptor Alpha* (CHEMBL206) that are reported as pChEMBL values.

# %%
activity = new_client.activity
res = activity.filter(target_chembl_id=selected_target).filter(standard_type="IC50")

# %%
df = pd.DataFrame.from_dict(res)

# %%
df
# Out:
#   action_type activity_comment  activity_id activity_properties  \
# 0        None             None      1468095                  []
# 1        None             None      1468243                  []
# 2        None             None      1468509                  []
# 3        None             None      1468524                  []
# 4        None             None      1468538                  []
# 5        None             None      1468787                  []
# 6        None             None      1469068                  []
# 7        None             None      1469708                  []
# 8        None             None      1469979                  []
# 9        None             None     18083052                  []
#
#   assay_chembl_id                                  assay_description  \
# 0    CHEMBL829541  Inhibition of [3H]17-beta-estradiol binding to...
# 1    CHEMBL829541  Inhibition of [3H]17-beta-estradiol binding to...
# 2    CHEMBL829541  Inhibition of [3H]17-beta-estradiol binding to...
# 3    CHEMBL829541  Inhibition of [3H]17-beta-estradiol binding to...
# 4    CHEMBL829541  Inhibition of [3H]17-beta-estradiol binding to...
# 5    CHEMBL829541  Inhibition of [3H]17-beta-estradiol binding to...
# 6    CHEMBL829541  Inhibition of [3H]17-beta-estradiol binding to...
# 7    CHEMBL829541  Inhibition of [3H]17-beta-estradiol binding to...
# 8    CHEMBL829541  Inhibition of [3H]17-beta-estradiol binding to...
# 9   CHEMBL4018000  Antagonist activity at estrogen receptor in mo...
#
#   assay_type assay_variant_accession assay_variant_mutation bao_endpoint  ...  \
# 0          B                    None                   None  BAO_0000190  ...
# 1          B                    None                   None  BAO_0000190  ...
# 2          B                    None                   None  BAO_0000190  ...
# 3          B                    None                   None  BAO_0000190  ...
# 4          B                    None                   None  BAO_0000190  ...
# 5          B                    None                   None  BAO_0000190  ...
# 6          B                    None                   None  BAO_0000190  ...
# 7          B                    None                   None  BAO_0000190  ...
# 8          B                    None                   None  BAO_0000190  ...
# 9          B                    None                   None  BAO_0000190  ...
#
#   target_organism         target_pref_name target_tax_id text_value  toid  \
# 0    Mus musculus  Estrogen receptor alpha         10090       None  None
# 1    Mus musculus  Estrogen receptor alpha         10090       None  None
# 2    Mus musculus  Estrogen receptor alpha         10090       None  None
# 3    Mus musculus  Estrogen receptor alpha         10090       None  None
# 4    Mus musculus  Estrogen receptor alpha         10090       None  None
# 5    Mus musculus  Estrogen receptor alpha         10090       None  None
# 6    Mus musculus  Estrogen receptor alpha         10090       None  None
# 7    Mus musculus  Estrogen receptor alpha         10090       None  None
# 8    Mus musculus  Estrogen receptor alpha         10090       None  None
# 9    Mus musculus  Estrogen receptor alpha         10090       None  None
#
#    type units    uo_units upper_value   value
# 0  IC50    nM  UO_0000065        None  1335.0
# 1  IC50    nM  UO_0000065        None  1629.0
# 2  IC50    nM  UO_0000065        None   132.0
# 3  IC50    nM  UO_0000065        None   199.0
# 4  IC50    nM  UO_0000065        None   423.0
# 5  IC50    nM  UO_0000065        None  2601.0
# 6  IC50    nM  UO_0000065        None   746.0
# 7  IC50    nM  UO_0000065        None  1089.0
# 8  IC50    nM  UO_0000065        None     2.2
# 9  IC50    nM  UO_0000065        None    33.2
#
# [10 rows x 46 columns]

# %%
selection = ['molecule_chembl_id', 'canonical_smiles', 'standard_value']
dfm = df[selection]
dfm.head(10)
# Out:
#   molecule_chembl_id                                   canonical_smiles  \
# 0       CHEMBL187673                       Oc1ccc(-c2nc3ccc(O)cc3o2)cc1
# 1       CHEMBL187392                       Oc1ccc(-c2nc3cc(O)ccc3o2)cc1
# 2       CHEMBL188528                   Oc1ccc(-c2nc3cc(O)cc(Br)c3o2)cc1
# 3       CHEMBL187207                Oc1cc(Br)c2oc(-c3ccc(O)c(F)c3)nc2c1
# 4       CHEMBL186513                  N#Cc1cc(O)cc2nc(-c3ccc(O)cc3)oc12
# 5       CHEMBL188230                  O=Cc1cc(O)cc2nc(-c3ccc(O)cc3)oc12
# 6       CHEMBL450940               C=Cc1cc(O)cc2nc(-c3ccc(O)c(F)c3)oc12
# 7       CHEMBL188882                       Oc1ccc(-c2noc3cc(O)ccc23)cc1
# 8          CHEMBL135  C[C@]12CC[C@@H]3c4ccc(O)cc4CC[C@H]3[C@@H]1CC[C...
# 9      CHEMBL2137046     CCC(=C(c1ccc(O)cc1)c1ccc(OCCN(C)C)cc1)c1ccccc1
#
#   standard_value
# 0         1335.0
# 1         1629.0
# 2          132.0
# 3          199.0
# 4          423.0
# 5         2601.0
# 6          746.0
# 7         1089.0
# 8            2.2
# 9           33.2

# %% [markdown]
# Finally we will save the resulting bioactivity data to a CSV file **bioactivity_data.csv**.

# %%
df.to_csv('tk_01_bioactivity_data_raw.csv', index=False)

# %% [markdown]
# ## **Handling missing data**
# If any compounds has missing value for the **standard_value** and **canonical_smiles** column then drop it.

# %%
df2 = df[df.standard_value.notna()]
df2 = df2[df.canonical_smiles.notna()]
df2
# Out:
# C:\Users\Mychael\AppData\Local\Temp\ipykernel_17924\3852201246.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df2 = df2[df.canonical_smiles.notna()]
#                                             action_type activity_comment  \
# 0                                                  None             None
# 1                                                  None             None
# 2                                                  None             None
# 3                                                  None             None
# 4                                                  None             None
# ...                                                 ...              ...
# 3534  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 3535  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 3536  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 3537  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 3538  {'action_type': 'INHIBITOR', 'description': 'N...             None
#
#       activity_id                                activity_properties  \
# 0           82585                                                 []
# 1           94540                                                 []
# 2          112960                                                 []
# 3          116766                                                 []
# 4          118017                                                 []
# ...           ...                                                ...
# 3534     25056466  [{'comments': None, 'relation': '=', 'result_f...
# 3535     25056467  [{'comments': None, 'relation': '=', 'result_f...
# 3536     25056468  [{'comments': None, 'relation': '=', 'result_f...
# 3537     25056469  [{'comments': None, 'relation': '=', 'result_f...
# 3538     25056470  [{'comments': None, 'relation': '=', 'result_f...
#
#      assay_chembl_id                                  assay_description  \
# 0       CHEMBL666794                 Inhibition of Cytochrome P450 19A1
# 1       CHEMBL666794                 Inhibition of Cytochrome P450 19A1
# 2       CHEMBL661700  In vitro inhibition of human Cytochrome P450 19A1
# 3       CHEMBL661700  In vitro inhibition of human Cytochrome P450 19A1
# 4       CHEMBL661700  In vitro inhibition of human Cytochrome P450 19A1
# ...              ...                                                ...
# 3534   CHEMBL5249084  Inhibition of human placental microsome aromat...
# 3535   CHEMBL5249084  Inhibition of human placental microsome aromat...
# 3536   CHEMBL5249084  Inhibition of human placental microsome aromat...
# 3537   CHEMBL5249084  Inhibition of human placental microsome aromat...
# 3538   CHEMBL5249085  Inhibition of human placental aromatase using ...
#
#      assay_type assay_variant_accession assay_variant_mutation bao_endpoint  \
# 0             B                    None                   None  BAO_0000190
# 1             B                    None                   None  BAO_0000190
# 2             B                    None                   None  BAO_0000190
# 3             B                    None                   None  BAO_0000190
# 4             B                    None                   None  BAO_0000190
# ...         ...                     ...                    ...          ...
# 3534          B                    None                   None  BAO_0000190
# 3535          B                    None                   None  BAO_0000190
# 3536          B                    None                   None  BAO_0000190
# 3537          B                    None                   None  BAO_0000190
# 3538          B                    None                   None  BAO_0000190
#
#       ... target_organism      target_pref_name target_tax_id text_value  \
# 0     ...    Homo sapiens  Cytochrome P450 19A1          9606       None
# 1     ...    Homo sapiens  Cytochrome P450 19A1          9606       None
# 2     ...    Homo sapiens  Cytochrome P450 19A1          9606       None
# 3     ...    Homo sapiens  Cytochrome P450 19A1          9606       None
# 4     ...    Homo sapiens  Cytochrome P450 19A1          9606       None
# ...   ...             ...                   ...           ...        ...
# 3534  ...    Homo sapiens  Cytochrome P450 19A1          9606       None
# 3535  ...    Homo sapiens  Cytochrome P450 19A1          9606       None
# 3536  ...    Homo sapiens  Cytochrome P450 19A1          9606       None
# 3537  ...    Homo sapiens  Cytochrome P450 19A1          9606       None
# 3538  ...    Homo sapiens  Cytochrome P450 19A1          9606       None
#
#       toid  type units    uo_units upper_value   value
# 0     None  IC50    uM  UO_0000065        None     7.1
# 1     None  IC50    uM  UO_0000065        None    50.0
# 2     None  IC50    uM  UO_0000065        None   0.238
# 3     None  IC50    uM  UO_0000065        None   0.057
# 4     None  IC50    uM  UO_0000065        None   0.054
# ...    ...   ...   ...         ...         ...     ...
# 3534  None  IC50    nM  UO_0000065        None   237.8
# 3535  None  IC50    nM  UO_0000065        None  1100.0
# 3536  None  IC50    nM  UO_0000065        None  2531.0
# 3537  None  IC50    nM  UO_0000065        None   252.4
# 3538  None  IC50    nM  UO_0000065        None    10.0
#
# [3463 rows x 46 columns]

# %%
len(df2.canonical_smiles.unique())
# Out:
# 2597

# %%
df2_nr = df2.drop_duplicates(['canonical_smiles'])
df2_nr
# Out:
#                                             action_type activity_comment  \
# 0                                                  None             None
# 1                                                  None             None
# 2                                                  None             None
# 3                                                  None             None
# 4                                                  None             None
# ...                                                 ...              ...
# 3532  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 3533  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 3534  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 3535  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 3536  {'action_type': 'INHIBITOR', 'description': 'N...             None
#
#       activity_id                                activity_properties  \
# 0           82585                                                 []
# 1           94540                                                 []
# 2          112960                                                 []
# 3          116766                                                 []
# 4          118017                                                 []
# ...           ...                                                ...
# 3532     25056464  [{'comments': None, 'relation': '=', 'result_f...
# 3533     25056465  [{'comments': None, 'relation': '=', 'result_f...
# 3534     25056466  [{'comments': None, 'relation': '=', 'result_f...
# 3535     25056467  [{'comments': None, 'relation': '=', 'result_f...
# 3536     25056468  [{'comments': None, 'relation': '=', 'result_f...
#
#      assay_chembl_id                                  assay_description  \
# 0       CHEMBL666794                 Inhibition of Cytochrome P450 19A1
# 1       CHEMBL666794                 Inhibition of Cytochrome P450 19A1
# 2       CHEMBL661700  In vitro inhibition of human Cytochrome P450 19A1
# 3       CHEMBL661700  In vitro inhibition of human Cytochrome P450 19A1
# 4       CHEMBL661700  In vitro inhibition of human Cytochrome P450 19A1
# ...              ...                                                ...
# 3532   CHEMBL5249083  Inhibition of recombinant human aromatase prei...
# 3533   CHEMBL5249083  Inhibition of recombinant human aromatase prei...
# 3534   CHEMBL5249084  Inhibition of human placental microsome aromat...
# 3535   CHEMBL5249084  Inhibition of human placental microsome aromat...
# 3536   CHEMBL5249084  Inhibition of human placental microsome aromat...
#
#      assay_type assay_variant_accession assay_variant_mutation bao_endpoint  \
# 0             B                    None                   None  BAO_0000190
# 1             B                    None                   None  BAO_0000190
# 2             B                    None                   None  BAO_0000190
# 3             B                    None                   None  BAO_0000190
# 4             B                    None                   None  BAO_0000190
# ...         ...                     ...                    ...          ...
# 3532          B                    None                   None  BAO_0000190
# 3533          B                    None                   None  BAO_0000190
# 3534          B                    None                   None  BAO_0000190
# 3535          B                    None                   None  BAO_0000190
# 3536          B                    None                   None  BAO_0000190
#
#       ... target_organism      target_pref_name target_tax_id text_value  \
# 0     ...    Homo sapiens  Cytochrome P450 19A1          9606       None
# 1     ...    Homo sapiens  Cytochrome P450 19A1          9606       None
# 2     ...    Homo sapiens  Cytochrome P450 19A1          9606       None
# 3     ...    Homo sapiens  Cytochrome P450 19A1          9606       None
# 4     ...    Homo sapiens  Cytochrome P450 19A1          9606       None
# ...   ...             ...                   ...           ...        ...
# 3532  ...    Homo sapiens  Cytochrome P450 19A1          9606       None
# 3533  ...    Homo sapiens  Cytochrome P450 19A1          9606       None
# 3534  ...    Homo sapiens  Cytochrome P450 19A1          9606       None
# 3535  ...    Homo sapiens  Cytochrome P450 19A1          9606       None
# 3536  ...    Homo sapiens  Cytochrome P450 19A1          9606       None
#
#       toid  type units    uo_units upper_value   value
# 0     None  IC50    uM  UO_0000065        None     7.1
# 1     None  IC50    uM  UO_0000065        None    50.0
# 2     None  IC50    uM  UO_0000065        None   0.238
# 3     None  IC50    uM  UO_0000065        None   0.057
# 4     None  IC50    uM  UO_0000065        None   0.054
# ...    ...   ...   ...         ...         ...     ...
# 3532  None  IC50    nM  UO_0000065        None    13.0
# 3533  None  IC50    nM  UO_0000065        None    13.0
# 3534  None  IC50    nM  UO_0000065        None   237.8
# 3535  None  IC50    nM  UO_0000065        None  1100.0
# 3536  None  IC50    nM  UO_0000065        None  2531.0
#
# [2597 rows x 46 columns]

# %% [markdown]
# ## **Data pre-processing of the bioactivity data**

# %% [markdown]
# ### **Combine the 3 columns (molecule_chembl_id,canonical_smiles,standard_value) and bioactivity_class into a DataFrame**

# %%
selection = ['molecule_chembl_id','canonical_smiles','standard_value']
df3 = df2_nr[selection]
df3
# Out:
#      molecule_chembl_id                                   canonical_smiles  \
# 0          CHEMBL341591          CC12CCC(O)CC1=CCC1C2CCC2(C)C(CC3CN3)CCC12
# 1         CHEMBL2111947  C[C@]12CC[C@H]3[C@@H](CC=C4C[C@@H](O)CC[C@@]43...
# 2          CHEMBL431859      CCn1c(C(c2ccc(F)cc2)n2ccnc2)c(C)c2cc(Br)ccc21
# 3          CHEMBL113637             CCn1cc(C(c2ccc(F)cc2)n2ccnc2)c2ccccc21
# 4          CHEMBL112021                 Clc1ccccc1Cn1cc(Cn2ccnc2)c2ccccc21
# ...                 ...                                                ...
# 3532      CHEMBL5285636                COc1ccc(C(=O)c2cccc(Cn3ccnc3)c2)cc1
# 3533      CHEMBL5266533                 O=C(c1ccc(O)cc1)c1cccc(Cn2ccnc2)c1
# 3534      CHEMBL5278229                COc1ccc(C(=O)c2ccc(Cn3ccnc3)cc2)cc1
# 3535      CHEMBL5275747                 O=C(c1ccc(O)cc1)c1ccc(Cn2ccnc2)cc1
# 3536      CHEMBL5273068         O=C(c1ccc(Cn2ccnc2)cc1)c1ccc(-c2ccccc2)cc1
#
#      standard_value
# 0            7100.0
# 1           50000.0
# 2             238.0
# 3              57.0
# 4              54.0
# ...             ...
# 3532           13.0
# 3533           13.0
# 3534          237.8
# 3535         1100.0
# 3536         2531.0
#
# [2597 rows x 3 columns]

# %% [markdown]
# Saves dataframe to CSV file

# %%
df3.to_csv('tk_02_bioactivity_data_preprocessed.csv', index=False)

# %% [markdown]
# ### **Labeling compounds as either being active, inactive or intermediate**
# The bioactivity data is in the IC50 unit. Compounds having values of less than 1000 nM will be considered to be **active** while those greater than 10,000 nM will be considered to be **inactive**. As for those values in between 1,000 and 10,000 nM will be referred to as **intermediate**.

# %%
df4 = pd.read_csv('kaa_02_bioactivity_data_preprocessed.csv')

# %%
bioactivity_threshold = []
for i in df4.standard_value:
  if float(i) >= 10000:
    bioactivity_threshold.append("inactive")
  elif float(i) <= 1000:
    bioactivity_threshold.append("active")
  else:
    bioactivity_threshold.append("intermediate")

# %%
bioactivity_class = pd.Series(bioactivity_threshold, name='class')
df5 = pd.concat([df4, bioactivity_class], axis=1)
df5
# Out:
#      molecule_chembl_id                                   canonical_smiles  \
# 0          CHEMBL192928  CC(C)(C)c1ccc(C(=O)Nc2[nH]nc3c2CN(C(=O)Cc2ccsc...
# 1          CHEMBL191816  CC(C)(C)c1ccc(C(=O)Nc2n[nH]c3c2CN(C(=O)c2ccco2...
# 2          CHEMBL192575  CC(C)(C)c1ccc(C(=O)Nc2n[nH]c3c2CN(C(=O)Cc2cccc...
# 3          CHEMBL191402  CCc1cccc(CC)c1NC(=O)N1Cc2[nH]nc(NC(=O)c3ccc(C(...
# 4          CHEMBL363857  CN1CCN(c2ccc(C(=O)Nc3[nH]nc4c3CN(C(=O)Cc3ccsc3...
# ...                 ...                                                ...
# 3186      CHEMBL5274495  CC(C)(C)c1cc(NC(=O)Nc2ncc(CCNc3ncnc4[nH]c(-c5c...
# 3187      CHEMBL5286283  Cc1cc(S(=O)(=O)Nc2ccc(/C=C3\SC(=O)N(CC4(C)CCCC...
# 3188      CHEMBL5278077            NC(=O)c1ccc(Nc2ncc(F)c(Nc3ccccc3)n2)cc1
# 3189      CHEMBL5271559            NC(=O)c1cnc(Nc2cccc(O)n2)cc1Nc1ccccc1Cl
# 3190      CHEMBL5285754      CS(=O)(=O)N1CCC2(CC1)N=C(c1ccc(Br)cc1)C(=O)N2
#
#       standard_value         class
# 0                5.0        active
# 1               41.0        active
# 2              130.0        active
# 3              100.0        active
# 4               65.0        active
# ...              ...           ...
# 3186            15.0        active
# 3187            35.0        active
# 3188             5.4        active
# 3189          2500.0  intermediate
# 3190         21300.0      inactive
#
# [3191 rows x 4 columns]

# %% [markdown]
# Saves dataframe to CSV file

# %%
df5.to_csv('tk_03_bioactivity_data_curated.csv', index=False)

# %%
import os
from zipfile import ZipFile

# Define the folder containing the files to be zipped
folder = 'C:\\Users\\Mychael\\Downloads'

# Create a ZipFile object
with ZipFile('output.zip', 'w') as myzip:
    # Iterate over the files in the folder
    for file in os.listdir(folder):
        # Check if the file ends with .csv or .pdf
        if file.endswith(".csv") or file.endswith(".pdf"):
            # Write the file to the zip archive
            myzip.write(os.path.join(folder, file), file)
